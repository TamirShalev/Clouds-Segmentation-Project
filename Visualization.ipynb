# %%
# This is how your main project's directory should look like at the beginning.
# Ignore the 'Visualization.ipynb' file.
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 86F7-0E43
#
#  Directory of C:\Users\shale\Desktop\project
#
# 09/17/2020  09:58 AM    <DIR>          .
# 09/17/2020  09:58 AM    <DIR>          ..
# 09/17/2020  09:47 AM    <DIR>          .ipynb_checkpoints
# 09/17/2020  09:58 AM    <DIR>          __pycache__
# 09/17/2020  09:47 AM    <DIR>          data
# 09/13/2020  10:33 AM            13,249 datahandler.py
# 08/26/2020  08:01 PM             3,233 helper.py
# 09/13/2020  10:58 AM             2,659 main.py
# 09/13/2020  10:43 AM             1,761 model.py
# 09/17/2020  09:57 AM    <DIR>          models
# 09/17/2020  09:58 AM    <DIR>          output
# 09/14/2020  08:19 AM             5,732 predict_all_data.py
# 09/17/2020  09:40 AM    <DIR>          results
# 09/13/2020  10:23 AM             5,567 trainer.py
# 09/17/2020  09:46 AM             3,058 Visualization.ipynb
# 09/17/2020  09:47 AM    <DIR>          weights
#                7 File(s)         35,259 bytes
# ...

# %%
# Training the model.
# The train consists of a single epoch and just a few images on the train and test sets
# as this is just a demonstration of a training process.
# %run -i "main.py" data output --epochs 1 --batchsize 2 --num_classes 3 --using_unet 0 --train_all 0
# Out:
# Begin training process with the following properties:
# Number of epochs = 1
# Batchsize = 2
# Number of classes = 3
# Using unet: False
# Train the whole network: False
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
# Epoch 1/1
# ----------
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [01:18<00:00, 39.24s/it]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# Train Loss: 0.6762
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:35<00:00, 35.47s/it]
# Test Loss: 0.2630
# ...

# %%
# You can ignore the prints in between.
# %run -i "predict_all_data.py"
# Out:
#  25%|█████████████████████                                                               | 1/4 [00:18<00:54, 18.19s/it]
# 0.860475
#  50%|██████████████████████████████████████████                                          | 2/4 [00:35<00:36, 18.01s/it]
# 1.72930625
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [00:53<00:18, 18.05s/it]
# 2.611375
# ...
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
# 3.476775
#  50%|██████████████████████████████████████████                                          | 1/2 [00:17<00:17, 17.52s/it]
# 0.77639375
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:35<00:00, 17.91s/it]
# 1.56785625
# For architechture 3class_resnet_trainall: Training accuracy=0.86919375, Test accuracy = 0.783928125
# ...

# %%
# Observe you now have a "seg_results.p" file in your main directory
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 86F7-0E43
#
#  Directory of C:\Users\shale\Desktop\project
#
# 09/17/2020  10:18 AM    <DIR>          .
# 09/17/2020  10:18 AM    <DIR>          ..
# 09/17/2020  09:47 AM    <DIR>          .ipynb_checkpoints
# 09/17/2020  09:58 AM    <DIR>          __pycache__
# 09/17/2020  09:47 AM    <DIR>          data
# 09/13/2020  10:33 AM            13,249 datahandler.py
# 08/26/2020  08:01 PM             3,233 helper.py
# 09/13/2020  10:58 AM             2,659 main.py
# 09/13/2020  10:43 AM             1,761 model.py
# 09/17/2020  09:57 AM    <DIR>          models
# 09/17/2020  09:58 AM    <DIR>          output
# 09/17/2020  10:15 AM             5,731 predict_all_data.py
# 09/17/2020  09:40 AM    <DIR>          results
# 09/17/2020  10:18 AM        26,882,885 seg_results.p
# 09/13/2020  10:23 AM             5,567 trainer.py
# 09/17/2020  10:18 AM             5,610 Visualization.ipynb
# 09/17/2020  09:47 AM    <DIR>          weights
# ...

# %%
# Get visualizations on train & test sets.
# The last two images are the test images.
# %run -i "helper.py"
